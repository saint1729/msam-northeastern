# %% [markdown]
# # Homework:
#
# ## Analytic Problem 1: (3 Points)
#
# Consider the preditor prey equations where the prey population has a carrying capacity:
#
# \begin{align}
# X' &= aX\left(1-\frac XK\right) - c_1 XY\,,
# \\
# Y' &= c_2 XY - bY\,.
# \end{align}
#
# 1.a) Write down expressions for the nullclines and the equilibrium solutions.
#
# 1.b) There are two rough cases depending on the parameters: All equilibrium solutions lie in the model domain $X,Y\geq 0$ or one does not. Draw the trajectory diagram for both cases, including the nullclines.
#
# 1.c) Compute the Jacobian matrix.
#
# 1.d) Argue, using either the matrix or the trajectory diagrams, for the type of the equilibrium solutions.

# %% [markdown]
# 1.a)
#
# For null clines and equilibrium solutions,
# $$
#                                         X' = 0\\
#                                         Y' = 0
# $$
#
# $$
#                                 X \left(a\left(1-\frac{X}{K}\right)-c_1Y\right) = 0 \tag{1}
# $$
#
# $$
#                                Y \left(c_2X-b\right) = 0 \tag{2}
# $$
#
# From $(2)$, there are two possible solutions: $Y = 0$ or $c_2X-b = 0$. We need to look at each case.
#
# If $Y = 0$, then substituting this into $(1)$ gives $X = 0$ and $X = K$. The possible solutions are $(X, Y) = (0, 0)$ and $(X, Y) = (K, 0)$.
#
# If $X = \frac{b}{c_2}$, then substituting this into $(1)$ gives $Y = \frac{a\left(1-\frac{b}{c_2K}\right)}{c_1}$. The possible solution is $(X, Y) = \left(\frac{b}{c_2}, \frac{a(c_2K-b)}{c_1c_2K}\right)$.
#
#
# The equilibrium solutions are,
#
# $$
#                     (X, Y) = (0, 0) \quad (X, Y) = (K, 0) \quad (X, Y) = \left(\frac{b}{c_2}, \frac{a(c_2K-b)}{c_1c_2K}\right)
# $$
#
#
#
#
#
# 1.b)
#
# Assuming all parameters > 0,
#
# Let us assume, $K = 5 \,\, a = 1 \,\, c_1 = 1 \,\, c_2 = 1$
#
# ##### Case - 1:
#
# Let $b = 3$
#
# Then equilibrium point is in Quadrant - I and trajectory is as follows:
#
# <img src="1b_case1.png" />
#
#
# ##### Case - 2:
#
# Let $b = 7$
#
# Then equilibrium point is in Quadrant - IV and trajectory is as follows:
#
# <img src="1b_case2.png" />
#
#
#
# 1.c)
#
# $$
#                     f_1^X = a - \frac{2aX}{K} - c_1Y  \quad   f_1^Y = -c_1X\\
#                     f_2^X = c_2Y \quad f_2^Y = c_2X - b
# $$
#
# Hence,
# $$
#                 J(X, Y) = \begin{pmatrix}
# a - \frac{2aX}{K} - c_1Y & -c_1X\\
# c_2Y & c_2X - b
# \end{pmatrix}
# $$
#
#
# 1.d)
#
#
#
# #### At $(X, Y) = (0, 0)$
#
# $$
#                 J(0, 0) = \begin{pmatrix}
# a & 0\\
# 0 & -b
# \end{pmatrix}
# $$
#
# Trace ($p$) = $a-b$
#
# Determinant ($q$) = $-ab$
#
# $$
# \begin{align}
# \Delta &= p^2-4q\\
#        &= (a - b)^2 + 4*a*b\\
#        &= (a+b)^2 \\
#        &> 0
# \end{align}
# $$
#
# Here, $\Delta > 0$ and $q < 0$. Hence,
#
# 1. if $p > 0$ (or $a > b$), then it is a <b>saddle point</b>.
# 2. if $p < 0$ (or $a < b$), then it is a <b>stable node</b>.
#
#
#
#
# #### At $(X, Y) = (K, 0)$
#
#
# $$
#                 J(K, 0) = \begin{pmatrix}
# -a & -c_1a\\
# 0 & c_2K-b
# \end{pmatrix}
# $$
#
# Trace ($p$) = $c_2K-b-a$
#
# Determinant ($q$) = $a(b-c_2K)$
#
# $$
# \begin{align}
# \Delta &= p^2-4q\\
#        &= (c_2K-b-a)^2 - 4*a(b-c_2K)\\
#        &= (c_2K-b+a)^2\\
#        &\ge 0
# \end{align}
# $$
#
# Here, $\Delta \ge 0$. Hence,
#
# 1. if $p > 0$ (or $K > \frac{a+b}{c_2}$) and $q < 0$ (or $K > \frac{b}{c_2}$), then it is a <b>saddle point</b>.
# 2. if $p < 0$ (or $K < \frac{a+b}{c_2}$), then it is a <b>stable point</b>.
#
# The case $p > 0$ and $q < 0$ is invalid here.
#
#
#
#
# #### At $(X, Y) = \left(\frac{b}{c_2}, \frac{a(c_2K-b)}{c_1c_2K}\right)$
#
#
# $$
#                 J\left(\frac{b}{c_2}, \frac{a(c_2K-b)}{c_1c_2K}\right) = \begin{pmatrix}
# -\frac{ab}{c_2K} & -\frac{c_1b}{c_2}\\
# \frac{a(c_2K-b)}{c_1K} & 0
# \end{pmatrix}
# $$
#
# Trace ($p$) = $-\frac{ab}{c_2K}$
#
# Determinant ($q$) = $\frac{ab(c_2K-b)}{c_2K}$
#
# $$
# \begin{align}
# \Delta &= p^2-4q\\
#        &= \frac{ab(ab-4c_2K(c_2K-b))}{(c_2K)^2}
# \end{align}
# $$
#
# Here, p < 0. If, $\Delta >= 0$. Hence,
#
# 1. if $\Delta \ge 0$ (or $ab \ge 4c_2K(c_2K-b)$) and $q \ge 0$, then it is a <b>stable node</b>.
# 2. if $\Delta \ge 0$ (or $ab \ge 4c_2K(c_2K-b)$) and $q < 0$, then it is a <b>saddle point</b>.
# 3. if $\Delta < 0$ (or $ab < 4c_2K(c_2K-b)$), then it is a <b>stable spiral</b>.

# %% [markdown]
# ## Case Study: Geese defy mathematical conventions?
#
# *In this case study, we will consider how to evaluate models with large numbers of parameters by using the nullclines and focusing on one parameter at a time. For large numbers of parameters the space of solutions may be complicated, but we can still try to understand what effect new terms have by focusing on the rough behavior of the nullclines, or by fixing all but single parameter of interest.*
#
# Classical exploitation theory has lead us to believe that where more grazing is available we will find more herbivores inflicting more pressure on the crops, thus keeping crop growth controlled. In <a href="https://esajournals.onlinelibrary.wiley.com/doi/pdf/10.2307/2265498">van de Koppel et al</a>, the authors argue that herbivores do not control the plant growth entirely.
#
# Their model, supported by empirical evidence, include the possibility of dense vegetation persisting with low herbivore grazing pressure, all in the absence of a predator. The observation of this maximal grazing pressure on large number of crops can be explain in a variety of ways. For example, in denser regions lack of light may impact stem development of plants, robbing the leaves of their protein content and making them less attractive to herbivores. Alternatively, these regions may be under watch by the few predators in the system, or herbivores may have greater difficulty penetrating them.
#
# Let $P$ and $H$ be the plant and herbivore densities respectively, with $P$ measure plant mass in $g/m^2$ and $H$ measuring  the number of herbivores per unit area in $num/m^2$ calculated from the number of droppings found. The standard form of the plant herbivore model is
#
# \begin{align}
# P’ &= G(P) – F(P)H
# \\
# H’ &= N(P)H
# \end{align}
#
# Where $G(P)$ is the growth function, $F(P)$ is the per capita consumption rate of a herbivore and $N(P)$ is the per-capita growth rate of herbivores.

# %% [markdown]
# Consider the first case of reduced digestion efficiency due to less nutritional forage in high density crops. Here, we take the per capita growth rate to decline in regions of high plant density. Let $P^*_1$ be the crop density under which there is too little food and herbivore growth is 0. Let $P_2^*$ to be the density above which there is too much vegetation and herbivore growth is again 0.
#
# They propose the following model
#
# \begin{align}
# P’ &= rP(1-P/K) – c_{max} \frac{P}{a+P} H
# \\
# H’ &= \left( e_{max}\frac{P}{a+P}  e^{-bP} - d \right)H
# \end{align}
#
# **1 Point for each of the following Questions**
#
# #### Question 2:
# Give a plausible interpretation of the constants $d$, $a$, $c_{max}$. These are all term’s we have discussed before.

# %% [markdown]
# 1. $d$ is the herbivore mortality rate.
# 2. $a$ is the plant mass per unit of area for which the per-capita consumption rate is half of the maximum value.
# 3. $c_{max}$ is the maximum value of per-capita consumption rate of a herbivore.

# %% [markdown]
# ---

# %% [markdown]
# We will be working around the parameter values
#
# |$K$|$r$|$a$|$b$|$c_{max}$|$e_{max}$|$d$|
# |--|--|--|--|--|--|--|
# |18|1|10|0.065|1|0.4|0.1|
#
# #### Question 3:
# Let us take a moment to understand the functios $N(P)$ and $F(P)$. Plot $N(P)$ vs $P$ and $F(P)$ vs $P$ for $P\in  [0,15]$.
#
# Use either the plots or the vectors to estimate the zeros of $N(P)$ up to 2 decimal places. These will be the nullclines assocaited to $H' = 0$.

# %% [markdown]
# ##### N(P) vs P
#
# <img src="2npvp.png">
#
# ##### F(P) vs P
#
# <img src="2fpvp.png">
#
#
# Zeroes of N(P) are, $P_1 \approx 5.7$ g/m<sup>2</sup> and $P_2 \approx 12$ g/m<sup>2</sup>.

# %% [markdown]
# ---

# %% [markdown]
# #### Question 4:
#
# We are interested in discovering the long term behavior of this model: are there parameters for which the plant-herbivore system settle into coexistance, or do the herbavores always eventually die out?
#
# Plot the vector feild associted to the plant-herbivore equations at the parameter values specified above, for $P,H\in [0,15]$.

# %%
from scipy.integrate import odeint
import matplotlib.pyplot as plt
import numpy as np


def model(X, t, params):
    P, H = X
    K, r, a, b, c_max, e_max, d = params
    dPdt = r * P * (1 - P / K) - c_max * P / (a + P) * H
    dHdt = (e_max * P / (a + P) * (np.e ** (-b * P)) - d) * H
    dXdt = [dPdt, dHdt]
    return dXdt

params = [18, 1, 10, 0.065, 1, 0.4, 0.1]

p = np.linspace(0, 15)
h = np.linspace(0, 15)
P, H = np.meshgrid(p, h)

U, V = model([P, H], 0, params)

# sol = odeint(model, t, [0, 0], (params,))

plt.figure(figsize = (12, 12))
plt.quiver(P, H , U, V, angles = 'xy', label = 'vector plot')
plt.xlabel('P(t)', size='21')
plt.ylabel('H(t)', size='21')
plt.legend()

# %% [markdown]
# In this case, the points with $P = 0$, $P \approx 5.7$ and $P = 18$ are stable and the point with $P \approx 12$ is unstable. Therefore, only in case of $P \approx 12$, there is a possibility of long-term coexistence.

# %% [markdown]
# #### Analytic Question 5:
#
# 5.a) Write down the 4 analytic equations for the distinct nullclines for system of equations. Using the numerical values you estimated in **Question 2**, give the equilibrium solutions to the system of equations for the given parameter values.
#
# 5.b) Add these to your plot from  **Question 3**. Compute the numerical solutions to the system of equations starting at $(P,H) = (10,13)$ and $(P,H) = (15,11)$ and plot them with the phase space vector field and the nullclines.

# %% [markdown]
# For nullclines, we have,
#
# $$
#                             P\left(r\left(1-\frac{P}{K}\right) - \frac{c_{max}H}{a+P}\right) = 0 \tag{1}
# $$
# $$
#                             H\left(e_{max}\frac{P}{a + P}e^{-bP}-d\right) = 0 \tag{2}
# $$
#
#
# From  (2) , there are two possible solutions: $H = 0$ or $\left(e_{max}\frac{P}{a + P}e^{-bP}-d\right) = 0$. We need to look at each case.
#
# If $H = 0$, then substituting this into (1) gives $P = 0$ or $P = K$. The possible solutions are $(P, H) = (0, 0)$ and $(P, H) = (K, 0)$. After subsituting the parameters this becomes $(P, H) = (0, 0)$ and $(P, H) = (18, 0)$.
#
# If $\left(e_{max}\frac{P}{a + P}e^{-bP} - d\right) = 0$, after substituting the parameter we get two solutions $P \approx 5.7$ and $P \approx 12$. Substituting this into (1) gives the solutions $(P, H) \approx (5.7, 10.73)$ and $(P, H) \approx (12, 7.33)$.
#
# The equilibrium solutions are,
#
# $$
#                         (P, H) = (0, 0) \quad (P, H) = (18, 0) \quad (P, H) \approx (5.7, 10.73) \quad (P, H) \approx (12, 7.33)
# $$

# %%
def model(X, t, params):
    P, H = X
    K, r, a, b, c_max, e_max, d = params
    dPdt = r * P * (1 - P / K) - c_max * P / (a + P) * H
    dHdt = (e_max * P / (a + P) * (np.e ** (-b * P)) - d) * H
    dXdt = [dPdt, dHdt]
    return dXdt

params = [18, 1, 10, 0.065, 1, 0.4, 0.1]

p = np.linspace(0, 20, 25)
h = np.linspace(0, 20, 25)
P, H = np.meshgrid(p, h)

U, V = model([P, H], 0, params)


def null_clines(number, params):
    K, r, a, b, c_max, e_max, d = params
    if number == 1:
        P = np.linspace(0, 20, 100)
        H = [0] * len(P)
        label = 'H = 0'
        return [P, H, label]
    elif number == 2:
        H = np.linspace(0, 20, 100)
        P = [0] * len(H)
        label = 'P = 0'
        return [P, H, label]
    elif number == 3:
        H = np.linspace(0, 20, 100)
        P = [5.7] * len(H)
        label = 'P = 5.7'
        return [P, H, label]
    elif number == 4:
        H = np.linspace(0, 20, 100)
        P = [12] * len(H)
        label = 'P = 12'
        return [P, H, label]
    elif number == 5:
        P = np.linspace(0, 20, 100)
        H = (r * (1 - P / K) * (a + P)) / c_max
        label = 'H = f(P) (a second-degree polynomial)'
        return [P, H, label]

sol1 = null_clines(1, params)
sol2 = null_clines(2, params)
sol3 = null_clines(3, params)
sol4 = null_clines(4, params)
sol5 = null_clines(5, params)

plt.figure(figsize = (12, 12))

plt.plot(sol1[0], sol1[1], label = sol1[2])
plt.plot(sol2[0], sol2[1], label = sol2[2])
plt.plot(sol3[0], sol3[1], label = sol3[2])
plt.plot(sol4[0], sol4[1], label = sol4[2])
plt.plot(sol5[0], sol5[1], label = sol5[2])

plt.quiver(P, H , U, V, angles = 'xy', label = 'vector plot')

plt.xlabel('P(t) ($g/m^2$)', size='21')
plt.ylabel('H(t) ($number/m^2$)', size='21')

plt.legend()


print(model([10, 13], 0, params))
print(model([15, 11], 0, params))
# Out:
# [-2.0555555555555554, 0.05731901957864172]
# [-4.1, -0.10421218659326596]

# %% [markdown]
# #### Question 6: Changin the Plant Carrying Capacity
#
# Consider the plant carrying capacity $K$ as a variable parameter while holding all other parameters fixed. Copy your code from **Question 5** and plot the resulting diagram for $K = 5, 10, 20$ and 24. You should use 4 subplots to summarize your results, and clearly label the plots.

# %%
def model(X, t, params):
    P, H = X
    K, r, a, b, c_max, e_max, d = params
    dPdt = r * P * (1 - P / K) - c_max * P / (a + P) * H
    dHdt = (e_max * P / (a + P) * (np.e ** (-b * P)) - d) * H
    dXdt = [dPdt, dHdt]
    return dXdt

params = [18, 1, 10, 0.065, 1, 0.4, 0.1]

p = np.linspace(0, 25, 25)
h = np.linspace(0, 25, 25)
P, H = np.meshgrid(p, h)

U, V = model([P, H], 0, params)

def null_clines(number, params):
    K, r, a, b, c_max, e_max, d = params
    if number == 1:
        P = np.linspace(0, 25, 100)
        H = [0] * len(P)
        label = 'H = 0'
        return [P, H, label]
    elif number == 2:
        H = np.linspace(0, 25, 100)
        P = [0] * len(H)
        label = 'P = 0'
        return [P, H, label]
    elif number == 3:
        H = np.linspace(0, 25, 100)
        P = [5.7] * len(H)
        label = 'P = 5.7'
        return [P, H, label]
    elif number == 4:
        H = np.linspace(0, 25, 100)
        P = [12] * len(H)
        label = 'P = 12'
        return [P, H, label]
    elif number == 5:
        P = np.linspace(0, K, 100)
        H = (r * (1 - P / K) * (a + P)) / c_max
        label = 'H = f(P) (a second-degree polynomial)'
        return [P, H, label]


nrows = 2
ncols = 2
fig, axes = plt.subplots(nrows, ncols, figsize=(16, 16))

K_values = [5, 10, 20, 24]

row, col = 0, 0

p = np.linspace(0, 20, 25)
h = np.linspace(0, 20, 25)
P, H = np.meshgrid(p, h)

for index, K in enumerate(K_values):
    params[0] = K
    sol1 = null_clines(1, params)
    sol2 = null_clines(2, params)
    sol3 = null_clines(3, params)
    sol4 = null_clines(4, params)
    sol5 = null_clines(5, params)
    U, V = model([P, H], 0, params)
    axes[row, col].plot(sol1[0], sol1[1], label = sol1[2])
    axes[row, col].plot(sol2[0], sol2[1], label = sol2[2])
    axes[row, col].plot(sol3[0], sol3[1], label = sol3[2])
    axes[row, col].plot(sol4[0], sol4[1], label = sol4[2])
    axes[row, col].plot(sol5[0], sol5[1], label = sol5[2])
#     axes[row, col].plot(P, H, label = "P(t) vs H(t)")
    axes[row, col].quiver(P, H , U, V, angles = 'xy', label = 'vector plot')
    axes[row, col].set_title("K = " + str(K))
    axes[row, col].set_xlabel('P(t)')
    axes[row, col].set_ylabel('H(t)')
    col += 1
    if col >= ncols:
        row += 1
        col = 0

# %% [markdown]
# ---

# %% [markdown]
# #### Analytic Question 7:
#
# Fix all of the constants except $K$ as in **Question 2**. Compute the stability type of the leftmost equilibrium point by giving an expression for the Jacobean (this is tedious but not difficult) and computing it at the equilibrium point. Then, use the trace-determinant plane (or the eigenvalues directly) to determine when the point is stable, unstable, or semistable and when it is a node or a focus. You should give each range in terms of $K$.
#
# *Hint: In the expression for $\Delta$ in the trace determinant plane, it might be helpful to solve in terms of $L = 1/K$, not $K$ directly.*
#
# *Hint: This computation can be done by hand, but by now I don't need to test you're ability to do complex partial derivatives. I would highly recommend using sympy for this problem.
#
# https://docs.sympy.org/latest/tutorial/intro.html

# %% [markdown]
# Solution:
#
# Using sympy:

# %%
from sympy import symbols, diff, Matrix, solve, solveset, S
from scipy.optimize import fsolve

P, H, K, Peq = symbols('P H K Peq', real=True)

params = [1, 10, 0.065, 1, 0.4, 0.1]

L = 1 / K

r, a, b, c_max, e_max, d = params

f1 = P * (r * (1 - P * L) - c_max * H / (a + P))
f2 = H * (e_max * P / (a + P) * ((np.e) ** (-b * P)) - d)

f1P = diff(f1, P)
f1H = diff(f1, H)

f2P = diff(f2, P)
f2H = diff(f2, H)

J = Matrix([[f1P, f1H], [f2P, f2H]])

def func(x):
    params = [1, 10, 0.065, 1, 0.4, 0.1]
    r, a, b, c_max, e_max, d = params
    return (e_max * x / (a + x) * ((np.e) ** (-b * x)) - d)

x = np.array([0, 15])

eq_solutions = fsolve(func, x)

# Left most equilibrium point other than (0, 0) is at P = 5.7
P0 = eq_solutions[0]
H0 = r * (1 - P0 * L) * (a + P0) / c_max

JP0 = J.subs([(P, P0), (H, H0)])

p = JP0[0] + JP0[3]
q = JP0.det()

delta = p * p - 4 * q


p_lt_zero_interval = solveset(p < 0, K, S.Reals)
p_gt_zero_interval = solveset(p > 0, K, S.Reals)
p_eq_zero_interval = solveset(p, K, S.Reals)

q_lt_zero_interval = solveset(q < 0, K, S.Reals)
q_gt_zero_interval = solveset(q > 0, K, S.Reals)

delta_lt_zero_interval = solveset(delta < 0, K, S.Reals)
delta_gt_zero_interval = solveset(delta > 0, K, S.Reals)


stable_node_interval = delta_gt_zero_interval.intersect(p_lt_zero_interval).intersect(q_gt_zero_interval)
unstable_node_interval = delta_gt_zero_interval.intersect(p_gt_zero_interval).intersect(q_gt_zero_interval)

semistable_node_interval = q_lt_zero_interval

stable_spiral_interval = delta_lt_zero_interval.intersect(p_lt_zero_interval)
center_interval = delta_lt_zero_interval.intersect(p_eq_zero_interval)
unstable_spiral_interval = delta_lt_zero_interval.intersect(p_gt_zero_interval)


print("The equilibrium point is a stable node when K belongs to " + str(stable_node_interval))
print("The equilibrium point is an unstable node when K belongs to " + str(unstable_node_interval))

print("The equilibrium point is a semistable node when K belongs to " + str(semistable_node_interval))

print("The equilibrium point is a stable spiral when K belongs to " + str(stable_spiral_interval))
print("The equilibrium point is a center when K belongs to " + str(center_interval))
print("The equilibrium point is an unstable spiral when K belongs to " + str(unstable_spiral_interval))
# Out:
# The equilibrium point is a stable node when K belongs to Interval.open(5.64524506083809, 12.6662387419389)
# The equilibrium point is an unstable node when K belongs to Union(Interval.open(-oo, 0), Interval.open(218.701159352067, oo))
# The equilibrium point is a semistable node when K belongs to Interval.open(0, 5.64524506083809)
# The equilibrium point is a stable spiral when K belongs to Interval.open(12.6662387419389, 21.2904901216749)
# The equilibrium point is a center when K belongs to FiniteSet(21.2904901216749)
# The equilibrium point is an unstable spiral when K belongs to Interval.open(21.2904901216749, 218.701159352067)

# %% [markdown]
# #### Question 8:
#
# Summarize how the solutions, and overall behavior of the model chances for changes for changing $K$. Give distinct phases of the model in terms of $K$ and describe the types of behavior in each phase. You're results should be justified by the stability of the equilibrium solutions from your numerical simulations.

# %% [markdown]
# Solution:
#
#
# From above solutions, it is clear that there is no herbivore population if $K < 5.65$ or $K > 21.29$.
#
# For $K \in (5.65, 12.67)$, coexistence ensues from any initial densities.
#
# For $K \in (12.67, 21.29)$, where coexistence ensues from only a select number of initial conditions and the herbivores approach extinction otherwise, even with large initial densities.
