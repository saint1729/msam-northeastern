# %% [markdown]
# # Homework 4 - Heat Flow
#
#
# ## Problem 1
# In class and in Chapter 9, we derived the heat equation for a rectangular heat fin using Newtons Law of Cooling. In this problem, we will derive similar equations for the {\bf cylindrical heat fin}. \\
#
# <img src="https://gdurl.com/GTpW/download" width=400>
#
# Attached to thin pipe is a disk heat fin of thickness $h$, inner radius $r_1$ (the same as the pipe thickness) and outer radius $r_2$ (measured from the center of the pipe), heat flows radially. Heat is lost from the surface of the fin to the surrounding atmosphere (whose temperature is a constant $u_s$) according to Newtons law of Cooling.
#
# Derive the differential equation for the **equilibrium temperature** of the heat fin, assuming the temperature variation over the cross section of the heat fin is negligible.

# %% [markdown]
# <div style="background-color: #e9e9e9; padding: 10px 20px;">
# <i>Solution:</i>
#
#
# Assumptions:
#
# 1) Thickness of the heat fin $H$ to be small compared with its outer radius $r_2$.
# 2) Heat is lost from the surfaces of the heat fin to the surroundings (at temperature $u_s$) according to Newton's law of cooling.
# 3) Because most of the heat loss occurs from the faces of the fin, both top and bottom, the heat lost from the sides is ignored.
# 4) A further assumption is to neglect the temperature variation over the cross-section of the fin. This assumption is reasonable, provided the heat fin is thin (that is, $H << r_2$).
#
#
# The heat balance equation for the section is,
#
# rate of change of heat in section = rate heat conducted in at $r$ - rate heat conducted out at $r+\Delta r$ - rate heast lost to surroundings
#
# For the equilibrium temperature, the rate of change of heat in section is zero and so,
#
# rate heat conducted in at $r$ - rate heat conducted out at $r+\Delta r$ - rate heast lost to surroundings = 0 $\tag{1}$
#
#
# According to Newton's law (and Mean-Value Theorem),
#
# rate heat lost to surroundings
# $$
# \begin{align}
#         &= 2hS(U(r^*)-u_s)\\
#         &= 2h(\pi ((r+\Delta r)^2 - \pi r^2))(U(r^*)-u_s)\\
#         &= 2h \pi \Delta r(2 r + \Delta r)(U(r^*)-u_s)
# \end{align} \tag{2}
# $$
# for some $r < r^* < r + \Delta r$
#
#
# rate heat conducted in at $r$
# $$
# \begin{align}
#         &= J(r)A(r)
# \end{align} \tag{3}
# $$
#
#
# rate heat conducted in at $r + \Delta r$
# $$
# \begin{align}
#         &= J(r + \Delta r)A(r + \Delta r)
# \end{align} \tag{4}
# $$
#
#
# From (1), (2), (3) and (4), dividing both sides by $\Delta r$, we get,
#
# $$
#    -\left[\frac{J(r + \Delta r)A(r + \Delta r) - J(r)A(r)}{\Delta r}\right] = 2h \pi (2 r + \Delta r)(U(r^*)-u_s)
# $$
#
# Taking the limit as $\Delta r \to 0$ and substituting $J = -k \frac{dU}{dr}$ (Fourier's law) and $A(r) = 2 \pi r H$, we have,
#
# $$
#                             -\frac{d}{dr}\left[-k \frac{dU}{dr} 2 \pi r H\right] = 4\pi hr(U(r)-u_s)\\
#                             \frac{d}{dr}\left(r\frac{dU}{dr}\right) = \frac{2rh}{kH}(U-u_s)
# $$
#
# </div>

# %% [markdown]
# ## Case Study: Heating in a building
#
# In different parts of the world, dwellings and public buildings take on many differente and imaginative forms. Mud, corrigated iron, asbestos sheeting and glass are just examples of some of the huge varity of materials used. One aspect considered in constuction is climate, and certan materials and room configurations are used to enhance the heating and cooling mechinism of modern building. This is especailly a consideration in the face of added pressure for energy efficancy.
#
# Lets consider a model using Newtons law of cooling, where
#
# $$
# \left\{
# \begin{matrix}
# \text{rate}
# \\
# \text{heat}
# \\
# \text{transfer}
# \end{matrix}
# \right\}
# = \frac{S\times \Delta U}{R}
# $$
#
# where $S$ is the surface area between two regions, $\Delta U$ is the temperature different between the regions and $R$ is the resistance to heat transport. For a house, $R$ represents the total heat resistance due to the resistance of the materials making up the wall (including insulation, wallboard, struts, etc).
#
# Consider a simple schematic of a two room house
# <img src="https://gdurl.com/0tBr/download">
# A system of differentail equations, dependant on heat conduction, can be derived by considering the heat inputs and outputs in each of the two compartments. The resulting govering equations are
# \begin{align}
# M_A \frac{dU_A}{dt} &= \frac{S_{AO}}{R_{AO}}(u_s - U_A) + \frac{S_{AB}}{R_{AB}}(U_B - U_A)
# \\
# M_B \frac{dU_B}{dt} &= \frac{S_{BO}}{R_{BO}}(u_s - U_B) + \frac{S_{AB}}{R_{AB}}(U_A - U_B)
# \end{align}
# where
#
# * $M_i$ is the overall thermal mass of the air and materials in each room.
# * $S_{ij}$ is the surface area between the compartments $i$ and $j$, where $A$ represents room $A$, $B$ represents rooms $B$ and $O$ representst the outside.
# * $R_{ij}$ is the thermal resistance between each ccompartment.
#
# The thermal mass for each room can be computed as the sum of the thermal mass of the air, the thermal mass of the external wall and the termal mass of the internal wall:
#
# $$
# M_A = \rho_{air} c_{air} V_{air} + \rho_{external} c_{external} V_{external} +  \rho_{internal} c_{internal} V_{internal}
# $$
#
# We ignore heat loss through the roof for the moment.
#
# For this case study, we will fix the following parameters, calculated for $t$ in units of hours:
#
# |Heat Parameter|Parameter Value|
# |----------|------------|
# |$R_{AO} = R_{BO}$| 0.055 $m^2\cdot C h/kJ$|
# |$R_{AB}$ | 0.008 $m^2\cdot C h/kJ$|
# |$\rho_{air}$ | 1.2 $kg/m^3$|
# |$\rho_{external}$ | 2100 $kg/m^3$|
# |$\rho_{internal}$ | 803 $kg/m^3$|
# |$c_{air}$ |  1.005 $kJ/kg\cdot C$|
# |$c_{external}$ | .9 $kJ/kg\cdot C$|
# |$c_{internal}$ | 1.09 $kJ/kg\cdot C$|
#
# In addition, the building is assumed to have the following material thicknesses:
#
#
# |Heat Parameter | Parameter Value|
# |--|--|
# |External Wall Thickness| .2 m|
# |Internal Wall Thickness| .1 m|
# |Building Height| 3m|

# %% [markdown]
# #### Question 1:
#
# Solve the system of differential equations above. Assume the termperature of Room $A$ at $t=0$ is $20^\circ C$, the temperature of Room $B$ is $40^\circ C$ and the outside temperature is a constant $35^\circ C$.

# %% [markdown]
# <img src="thermal-model.png"></img>

# %%
from sympy import *
from sympy.abc import *
import sympy.functions.special.delta_functions as sfuncs
from sympy.plotting import plot as symplot


# parameter initialization

rho_air, rho_ext, rho_int = 1.2, 2100, 803
c_air, c_ext, c_int = 1.005, 0.9, 1.09
s_ao, s_bo, s_ab = (0.2 * 4.6) + (0.2 * 4.75) * 2, (0.2 * 4.6) + (0.2 * 4.75) * 2, 0.1 * 4.6
r_ao, r_bo, r_ab = 0.055, 0.055, 0.008
u_s = 35
m_A = rho_air * c_air * (5 * 10 * 3) + rho_ext * c_ext * (4.6 * 0.2 * 3 + 4.75 * 0.2 * 3 * 2) \
        + rho_int * c_int * (4.6 * 0.1 * 3)
m_B = rho_air * c_air * (5 * 10 * 3) + rho_ext * c_ext * (4.6 * 0.2 * 3 + 4.75 * 0.2 * 3 * 2) \
        + rho_int * c_int * (4.6 * 0.1 * 3)


# pretty printing initalization and symbol definition

init_printing()
t, C1, C2 = symbols("t C1 C2")
U_A, U_B =  symbols("U_A U_B", cls = Function, Function = True)



# writing first linear coupled differential equations
eq1 = Eq(m_A * diff(U_A(t), t), s_ao / r_ao * (u_s - U_A(t)) + s_ab / r_ab * (U_B(t) - U_A(t)))
eq2 = Eq(m_B * diff(U_B(t), t), s_bo / r_bo * (u_s - U_B(t)) + s_ab / r_ab * (U_A(t) - U_B(t)))


# using sympy's built-in dsolve method to solve the ODE

soln = dsolve((eq1, eq2))


# solve for integration constants

constants = solve((soln[0].subs(t, 0).subs(U_A(0), 20), soln[1].subs(t, 0).subs(U_B(0), 40)), {C1, C2})



# solve for analytical solutions after substituting the values

temperature_A = expand(soln[0].rhs.subs(constants))
temperature_B = soln[1].rhs.subs(constants)


# pretty printing the solutions

pprint("U_A(t) = " + str(temperature_A), use_unicode = True)
print()
pprint("U_B(t) = " + str(temperature_B), use_unicode = True)


# plotting the curves

start, end = 0, 2000

p1 = symplot(temperature_A, (t, start, end), line_color = 'blue', show = False)
p2 = symplot(temperature_B, (t, start, end), line_color = 'orange', show = False)

p1.append(p2[0])
p1.show()
# Out:
# U_A(t) = 35.0000000000001 - 9.99999999999999*exp(-0.00956790630982266*t) - 5.0
# *exp(-0.00295040960018588*t)
#
# U_B(t) = 35.0000000000001 + 9.99999999999999*exp(-0.00956790630982266*t) - 5.0
# *exp(-0.00295040960018588*t)

# %% [markdown]
# <div style="background-color: #e9e9e9; padding: 10px 20px;">
# Since it is impractical to assume that outside temperature will remain at $35 \, ^oC$ all the time, because of sunrise and sunset will cause difference in heat energy supplied, the above model is only hypothetical. A more realistic model is analysed below.
# </div>

# %% [markdown]
# #### Question 2: Day and Night
#
# Modify the model above the include a 24 hour day/night cycle. Assume that $t=0$ is the height of heat for the day at $35^\circ C$ and that the low point of heat for the day is 12 hours later and is $25^\circ C$.

# %%
from sympy import *
from sympy.abc import *
import sympy.functions.special.delta_functions as sfuncs
from sympy.plotting import plot as symplot
from sympy import Piecewise, log, ITE, piecewise_fold

rho_air, rho_ext, rho_int = 1.2, 2100, 803
c_air, c_ext, c_int = 1.005, 0.9, 1.09

s_ao, s_bo, s_ab = (0.2 * 4.6) + (0.2 * 4.75) * 2, (0.2 * 4.6) + (0.2 * 4.75) * 2, 0.1 * 4.6
r_ao, r_bo, r_ab = 0.055, 0.055, 0.008
u_s = 35
m_A = rho_air * c_air * (5 * 10 * 3) + rho_ext * c_ext * (4.6 * 0.2 * 3 + 4.75 * 0.2 * 3 * 2) \
        + rho_int * c_int * (4.6 * 0.1 * 3)
m_B = rho_air * c_air * (5 * 10 * 3) + rho_ext * c_ext * (4.6 * 0.2 * 3 + 4.75 * 0.2 * 3 * 2) \
        + rho_int * c_int * (4.6 * 0.1 * 3)


init_printing()

t, C1, C2 = symbols("t C1 C2")
U_A, U_B =  symbols("U_A U_B", cls = Function, Function = True)

u_s = 35

eq1 = Eq(m_A * diff(U_A(t), t), s_ao / r_ao * (u_s - U_A(t)) + s_ab / r_ab * (U_B(t) - U_A(t)))
eq2 = Eq(m_B * diff(U_B(t), t), s_bo / r_bo * (u_s - U_B(t)) + s_ab / r_ab * (U_A(t) - U_B(t)))

soln = dsolve((eq1, eq2))

constants = solve((soln[0].subs(t, 0).subs(U_A(0), 20), soln[1].subs(t, 0).subs(U_B(0), 40)), {C1, C2})

temperature_A_1 = expand(soln[0].rhs.subs(constants))
temperature_B_1 = soln[1].rhs.subs(constants)

U_A_12 = temperature_A_1.subs({t: 12})
U_B_12 = temperature_B_1.subs({t: 12})

pprint("U_A(t) = " + str(temperature_A_1) + " for 0 <= t < 12", use_unicode=True)
print()
pprint("U_B(t) = " + str(temperature_B_1) + " for 0 <= t < 12", use_unicode=True)

start1, end1 = 0, 12

p1 = symplot(temperature_A_1, (t, start1, end1), line_color = 'blue', show = False)
p2 = symplot(temperature_B_1, (t, start1, end1), line_color = 'orange', show = False)



u_s = 25

eq1 = Eq(m_A * diff(U_A(t), t), s_ao / r_ao * (u_s - U_A(t)) + s_ab / r_ab * (U_B(t) - U_A(t)))
eq2 = Eq(m_B * diff(U_B(t), t), s_bo / r_bo * (u_s - U_B(t)) + s_ab / r_ab * (U_A(t) - U_B(t)))

soln = dsolve((eq1, eq2))

constants = solve((soln[0].subs(t, 12).subs(U_A(12), U_A_12), soln[1].subs(t, 12).subs(U_B(12), U_B_12)), {C1, C2})

temperature_A_2 = expand(soln[0].rhs.subs(constants))
temperature_B_2 = soln[1].rhs.subs(constants)

print()
print()
pprint("U_A(t) = " + str(temperature_A_2) + " for 12 <= t < 24", use_unicode=True)
print()
pprint("U_B(t) = " + str(temperature_B_2) + " for 12 <= t < 24", use_unicode=True)

start2, end2 = 12, 24

p3 = symplot(temperature_A_2, (t, start2, end2), line_color = 'red', show = False)
p4 = symplot(temperature_B_2, (t, start2, end2), line_color = 'green', show = False)

p1.append(p2[0])
p1.append(p3[0])
p1.append(p4[0])

p1.show()
# Out:
# U_A(t) = 35.0000000000001 - 9.99999999999999*exp(-0.00956790630982266*t) - 5.0
# *exp(-0.00295040960018588*t) for 0 <= t < 12
#
# U_B(t) = 35.0000000000001 + 9.99999999999999*exp(-0.00956790630982266*t) - 5.0
# *exp(-0.00295040960018588*t) for 0 <= t < 12
#
#
# U_A(t) = 25.0 - 9.99999999999997*exp(-0.00956790630982266*t) + 5.3603913187311
# 5*exp(-0.00295040960018588*t) for 12 <= t < 24
#
# U_B(t) = 25.0 + 9.99999999999997*exp(-0.00956790630982266*t) + 5.3603913187311
# 5*exp(-0.00295040960018588*t) for 12 <= t < 24

# %% [markdown]
# <div style="background-color: #e9e9e9; padding: 10px 20px;">
# The shift in gradient after 12 hours can be clearly seen from above graph. Unfortunately, it is becoming a bit difficult to extend the model to 24+ hours, because sympy today is not supporting piecewise definitions of functions and if I use heaviside theta function to have a jump kind of junction sympy has some internal bugs. Several issues are logged. Few of them are mentioned below:
#
# https://github.com/sympy/sympy/issues/13376
# https://github.com/sympy/sympy/issues/12632
#
# Interesting fact is there are multiple issues w.r.t. heaviside theta function implementation in sympy. When I was trying to apply for GSoC back in 2012, I myself solved some issues :)
#
# One solution for this could be to write a generic function with initial conditions and time limits as input and expect to plot the graph between those limits. The questions asks for 24 hr and hence I didn't continue further. Please feel free to ask me if you need a generic extension for this.
# </div>

# %% [markdown]
# #### Question 3:
#
# Lets simulate the addition of an air conditioning unit to one of the rooms. A standard window unit removes approximatly $\kappa_A = 6000$ kJ of energy per hour. We modify the equations as follows
#
# \begin{align}
# M_A \frac{dU_A}{dt} &= \frac{S_{AO}}{R_{AO}}(u_s - U_A) + \frac{S_{AB}}{R_{AB}}(U_A - U_B) - \kappa_A
# \\
# M_B \frac{dU_B}{dt} &= \frac{S_{BO}}{R_{BO}}(u_s - U_B) + \frac{S_{AB}}{R_{AB}}(U_B - U_A)
# \end{align}
# Model this system of equations with the other paramters as above.
#
# *To think about: How do we understand the almost constant gap in temperature between the rooms?*

# %%
from sympy import *
from sympy.abc import *
import sympy.functions.special.delta_functions as sfuncs
from sympy.plotting import plot as symplot

rho_air, rho_ext, rho_int = 1.2, 2100, 803
c_air, c_ext, c_int = 1.005, 0.9, 1.09
s_ao, s_bo, s_ab = (0.2 * 4.6) + (0.2 * 4.75) * 2, (0.2 * 4.6) + (0.2 * 4.75) * 2, 0.1 * 4.6
r_ao, r_bo, r_ab = 0.055, 0.055, 0.008
u_s = 35
m_A = rho_air * c_air * (5 * 10 * 3) + rho_ext * c_ext * (4.6 * 0.2 * 3 + 4.75 * 0.2 * 3 * 2) \
        + rho_int * c_int * (4.6 * 0.1 * 3)
m_B = rho_air * c_air * (5 * 10 * 3) + rho_ext * c_ext * (4.6 * 0.2 * 3 + 4.75 * 0.2 * 3 * 2) \
        + rho_int * c_int * (4.6 * 0.1 * 3)

kappa_a = 6000

init_printing()

t, C1, C2 = symbols("t C1 C2")
U_A, U_B =  symbols("U_A U_B", cls = Function, Function = True)

eq1 = Eq(m_A * diff(U_A(t), t), s_ao / r_ao * (u_s - U_A(t)) + s_ab / r_ab * (U_B(t) - U_A(t)) - kappa_a)

eq2 = Eq(m_B * diff(U_B(t), t), s_bo / r_bo * (u_s - U_B(t)) + s_ab / r_ab * (U_A(t) - U_B(t)))

soln = dsolve((eq1, eq2))

constants = solve((soln[0].subs(t, 0).subs(U_A(0), 20), soln[1].subs(t, 0).subs(U_B(0), 40)), {C1, C2})

temperature_A = expand(soln[0].rhs.subs(constants))
temperature_B = soln[1].rhs.subs(constants)

pprint("U_A(t) = " + str(temperature_A), use_unicode = True)
print()
pprint("U_B(t) = " + str(temperature_B), use_unicode = True)

start, end = 0, 12

p1 = symplot(temperature_A, (t, start, end), line_color = 'blue', show = False)
p2 = symplot(temperature_B, (t, start, end), line_color = 'orange', show = False)

p1.append(p2[0])
p1.show()
# Out:
# U_A(t) = -41.5532845526564 + 8.04264625478405*exp(-0.00956790630982266*t) + 53
# .5106382978724*exp(-0.00295040960018588*t)
#
# U_B(t) = -5.46799204308833 - 8.04264625478404*exp(-0.00956790630982266*t) + 53
# .5106382978724*exp(-0.00295040960018588*t)

# %% [markdown]
# <div style="background-color: #e9e9e9; padding: 10px 20px;">
# To extend this beyond 12 hr. we need to write a generic function as discussed in the above question.
# </div>

# %% [markdown]
# #### Question 4:
# If you are interested in keeping Room $A$ cool, you could either double the cooling factor of the air conditioning unit, or try to insulate the wall between Rooms $A$ and Room $B$. Rigid panel polystyreen has as $R$ value of 0.9435. Which is the better way to keep Room $A$ cool?

# %%
from sympy import *
from sympy.abc import *
import sympy.functions.special.delta_functions as sfuncs
from sympy.plotting import plot as symplot

rho_air, rho_ext, rho_int = 1.2, 2100, 803
c_air, c_ext, c_int = 1.005, 0.9, 1.09

s_ao, s_bo, s_ab = (0.2 * 4.6) + (0.2 * 4.75) * 2, (0.2 * 4.6) + (0.2 * 4.75) * 2, 0.1 * 4.6
r_ao, r_bo, r_ab = 0.055, 0.055, 0.008
u_s = 35
m_A = rho_air * c_air * (5 * 10 * 3) + rho_ext * c_ext * (4.6 * 0.2 * 3 + 4.75 * 0.2 * 3 * 2) \
        + rho_int * c_int * (4.6 * 0.1 * 3)
m_B = rho_air * c_air * (5 * 10 * 3) + rho_ext * c_ext * (4.6 * 0.2 * 3 + 4.75 * 0.2 * 3 * 2) \
        + rho_int * c_int * (4.6 * 0.1 * 3)

kappa_a = 6000

init_printing()

t, C1, C2 = symbols("t C1 C2")
U_A, U_B =  symbols("U_A U_B", cls = Function, Function = True)

eq1 = Eq(m_A * diff(U_A(t), t), s_ao / r_ao * (u_s - U_A(t)) + s_ab / r_ab * (U_B(t) - U_A(t)) - 2 * kappa_a)
eq2 = Eq(m_B * diff(U_B(t), t), s_bo / r_bo * (u_s - U_B(t)) + s_ab / r_ab * (U_A(t) - U_B(t)))

soln = dsolve((eq1, eq2))

constants = solve((soln[0].subs(t, 0).subs(U_A(0), 20), soln[1].subs(t, 0).subs(U_B(0), 40)), {C1, C2})

temperature_A = expand(soln[0].rhs.subs(constants))
temperature_B = soln[1].rhs.subs(constants)

pprint("U_A(t) = " + str(temperature_A), use_unicode = True)
print()
pprint("U_B(t) = " + str(temperature_B), use_unicode = True)

start, end = 0, 12

p1 = symplot(temperature_A, (t, start, end), line_color = 'blue', show = False)
p2 = symplot(temperature_B, (t, start, end), line_color = 'orange', show = False)

p1.append(p2[0])



r_ab += 0.9435

eq1 = Eq(m_A * diff(U_A(t), t), s_ao / r_ao * (u_s - U_A(t)) + s_ab / r_ab * (U_B(t) - U_A(t)) - kappa_a)
eq2 = Eq(m_B * diff(U_B(t), t), s_bo / r_bo * (u_s - U_B(t)) + s_ab / r_ab * (U_A(t) - U_B(t)))

soln = dsolve((eq1, eq2))

constants = solve((soln[0].subs(t, 0).subs(U_A(0), 20), soln[1].subs(t, 0).subs(U_B(0), 40)), {C1, C2})

temperature_A = expand(soln[0].rhs.subs(constants))
temperature_B = soln[1].rhs.subs(constants)

print()
print()
pprint("After insulation, U_A(t) = " + str(temperature_A), use_unicode = True)
print()
pprint("After insulation, U_B(t) = " + str(temperature_B), use_unicode = True)


p3 = symplot(temperature_A, (t, start, end), line_color = 'red', show = False)
p4 = symplot(temperature_B, (t, start, end), line_color = 'green', show = False)


p1.append(p3[0])
p1.append(p4[0])

p1.show()
# Out:
# U_A(t) = -118.106569105313 + 26.0852925095681*exp(-0.00956790630982266*t) + 11
# 2.021276595745*exp(-0.00295040960018588*t)
#
# U_B(t) = -45.9359840861767 - 26.0852925095681*exp(-0.00956790630982266*t) + 11
# 2.021276595745*exp(-0.00295040960018588*t)
#
#
# After insulation, U_A(t) = -80.9383130252696 + 47.4276747273972*exp(-0.0030060
# 480381019*t) + 53.5106382978724*exp(-0.00295040960018588*t)
#
# After insulation, U_B(t) = 33.9170364295248 - 47.4276747273974*exp(-0.00300604
# 80381019*t) + 53.5106382978726*exp(-0.00295040960018588*t)

# %% [markdown]
# <div style="background-color: #e9e9e9; padding: 10px 20px;">
# We need to compare blue and red curves.
#
# Assuming outside temperature is constant for 12 hours,
#
# from the graph it is clear that upto approximately 1 hours we don't see much difference between "doubling the air-condition" and "polystyrene + air-condition". But, in a long run, I think "doubling the air-condition" is better.
#
# This subject is super awesome. By far the best course I have taken in my life till now (better than Probability) :)
# </div>

# %% [markdown]
# #### Question 5:
#
# Lets model adding a third $5\times 5$ room to the building using the three equations
#
# \begin{align}
# M_A \frac{dU_A}{dt} &= \frac{S_{AO}}{R_{AO}}(u_s - U_A) + \frac{S_{AB}}{R_{AB}}(U_B - U_A) - \kappa_A
# \\
# M_B \frac{dU_B}{dt} &= \frac{S_{BO}}{R_{BO}}(u_s - U_B) + \frac{S_{AB}}{R_{AB}}(U_A - U_B)+\frac{S_{BC}}{R_{BC}}(U_C - U_B)
# \\
# M_C \frac{dU_C}{dt} &= \frac{S_{CO}}{R_{CO}}(u_s - U_C) + \frac{S_{BC}}{R_{BC}}(U_B - U_C)
# \end{align}
#
# Model the effect of removing $\kappa_A = 6000$ kJ of energy per hour of heat energy due to air conditioning in Room $A$ vs providing air conditioning to Room $B$. How much of a difference do you find?
#
# How does that difference change if we use the insulation from Question 4?

# %%
from sympy import *
from sympy.abc import *
import sympy.functions.special.delta_functions as sfuncs
from sympy.plotting import plot as symplot

rho_air, rho_ext, rho_int = 1.2, 2100, 803
c_air, c_ext, c_int = 1.005, 0.9, 1.09

s_ao, s_bo, s_co, s_ab, s_bc = (0.2 * 4.6) + (0.2 * 4.75) * 2, (0.2 * 4.6) + (0.2 * 4.75) * 2 \
        , (0.2 * 4.6) + (0.2 * 4.75) * 2, 0.1 * 4.6, 0.1 * 4.6
r_ao, r_bo, r_co, r_ab, r_bc = 0.055, 0.055, 0.055, 0.008, 0.008
u_s = 35

m_A = rho_air * c_air * (5 * 10 * 3) + rho_ext * c_ext * (4.6 * 0.2 * 3 + 4.75 * 0.2 * 3 * 2) \
        + rho_int * c_int * (4.6 * 0.1 * 3)
m_B = rho_air * c_air * (5 * 10 * 3) + rho_ext * c_ext * (4.6 * 0.2 * 3 + 4.75 * 0.2 * 3 * 2) \
        + rho_int * c_int * (4.6 * 0.1 * 3)
m_C = rho_air * c_air * (5 * 10 * 3) + rho_ext * c_ext * (4.6 * 0.2 * 3 + 4.75 * 0.2 * 3 * 2) \
        + rho_int * c_int * (4.6 * 0.1 * 3)


kappa_a, kappa_b = 6000, 6000

init_printing()

t, C1, C2, C3 = symbols("t C1 C2 C3")
U_A, U_B, U_C =  symbols("U_A U_B U_C", cls = Function, Function = True)


# air-conditioning in Room A

eq1 = Eq(m_A * diff(U_A(t), t), s_ao / r_ao * (u_s - U_A(t)) + s_ab / r_ab * (U_B(t) - U_A(t)) - kappa_a)
eq2 = Eq(m_B * diff(U_B(t), t), s_bo / r_bo * (u_s - U_B(t)) + s_ab / r_ab * (U_A(t) - U_B(t)) + s_bc / r_bc * (U_C(t) - U_B(t)))
eq3 = Eq(m_C * diff(U_C(t), t), s_co / r_co * (u_s - U_C(t)) + s_bc / r_bc * (U_B(t) - U_C(t)))

eqs = [eq1, eq2, eq3]

dsolve(eqs, [U_A(t), U_B(t), U_C(t)])

soln = [U_A(t), U_B(t), U_C(t)]

constants = solve((soln[0].subs(t, 0).subs(U_A(0), 20), soln[1].subs(t, 0).subs(U_B(0), 40), soln[2].subs(t, 0).subs(U_C(0), 40)), {C1, C2, C3})

temperature_A = expand(soln[0].rhs.subs(constants))
temperature_B = soln[1].rhs.subs(constants)
temperature_C = soln[2].rhs.subs(constants)

print("With air conditioning in Room A")
pprint("U_A(t) = " + str(temperature_A), use_unicode = True)
print()
pprint("U_B(t) = " + str(temperature_B), use_unicode = True)
print()
pprint("U_C(t) = " + str(temperature_C), use_unicode = True)

start, end = 0, 40

p1 = symplot(temperature_A, (t, start, end), line_color = 'blue', show = False)
p2 = symplot(temperature_B, (t, start, end), line_color = 'orange', show = False)
p3 = symplot(temperature_C, (t, start, end), line_color = 'brown', show = False)

p1.append(p2[0])
p1.append(p3[0])


# air-conditioning in Room B

eq1 = Eq(m_A * diff(U_A(t), t), s_ao / r_ao * (u_s - U_A(t)) + s_ab / r_ab * (U_B(t) - U_A(t)))
eq2 = Eq(m_B * diff(U_B(t), t), s_bo / r_bo * (u_s - U_B(t)) + s_ab / r_ab * (U_A(t) - U_B(t)) + s_bc / r_bc * (U_C(t) - U_B(t)) - kappa_b)
eq3 = Eq(m_C * diff(U_C(t), t), s_co / r_co * (u_s - U_C(t)) + s_bc / r_bc * (U_B(t) - U_C(t)))

eqs = [eq1, eq2, eq3]

dsolve(eqs, [U_A(t), U_B(t), U_C(t)])

soln = [U_A(t), U_B(t), U_C(t)]

constants = solve((soln[0].subs(t, 0).subs(U_A(0), 20), soln[1].subs(t, 0).subs(U_B(0), 40), soln[2].subs(t, 0).subs(U_C(0), 40)), {C1, C2, C3})

temperature_A = expand(soln[0].rhs.subs(constants))
temperature_B = soln[1].rhs.subs(constants)
temperature_C = soln[2].rhs.subs(constants)

print()
print()
print("With air conditioning in Room B")
pprint("U_A(t) = " + str(temperature_A), use_unicode = True)
print()
pprint("U_B(t) = " + str(temperature_B), use_unicode = True)
print()
pprint("U_C(t) = " + str(temperature_C), use_unicode = True)

start, end = 0, 40

p4 = symplot(temperature_A, (t, start, end), line_color = 'red', show = False)
p5 = symplot(temperature_B, (t, start, end), line_color = 'green', show = False)
p6 = symplot(temperature_C, (t, start, end), line_color = 'yellow', show = False)

p1.append(p4[0])
p1.append(p5[0])
p1.append(p6[0])



# thermal resistance with air-conditioning in A

r_ab += 0.9435
r_bc += 0.9435

eq1 = Eq(m_A * diff(U_A(t), t), s_ao / r_ao * (u_s - U_A(t)) + s_ab / r_ab * (U_B(t) - U_A(t)) - kappa_a)
eq2 = Eq(m_B * diff(U_B(t), t), s_bo / r_bo * (u_s - U_B(t)) + s_ab / r_ab * (U_A(t) - U_B(t)) + s_bc / r_bc * (U_C(t) - U_B(t)))
eq3 = Eq(m_C * diff(U_C(t), t), s_co / r_co * (u_s - U_C(t)) + s_bc / r_bc * (U_B(t) - U_C(t)))

eqs = [eq1, eq2, eq3]

dsolve(eqs, [U_A(t), U_B(t), U_C(t)])

soln = [U_A(t), U_B(t), U_C(t)]

constants = solve((soln[0].subs(t, 0).subs(U_A(0), 20), soln[1].subs(t, 0).subs(U_B(0), 40), soln[2].subs(t, 0).subs(U_C(0), 40)), {C1, C2, C3})

temperature_A = expand(soln[0].rhs.subs(constants))
temperature_B = soln[1].rhs.subs(constants)
temperature_C = soln[2].rhs.subs(constants)

print()
print()
print("With air-conditioning in A and insulation of walls between A & B, walls between B & C")
pprint("U_A(t) = " + str(temperature_A), use_unicode = True)
print()
pprint("U_B(t) = " + str(temperature_B), use_unicode = True)
print()
pprint("U_C(t) = " + str(temperature_C), use_unicode = True)

start, end = 0, 40

p7 = symplot(temperature_A, (t, start, end), line_color = 'pink', show = False)
p8 = symplot(temperature_B, (t, start, end), line_color = 'gray', show = False)
p9 = symplot(temperature_C, (t, start, end), line_color = 'violet', show = False)

p1.append(p7[0])
p1.append(p8[0])
p1.append(p9[0])



# thermal resistance with air-conditioning in B

eq1 = Eq(m_A * diff(U_A(t), t), s_ao / r_ao * (u_s - U_A(t)) + s_ab / r_ab * (U_B(t) - U_A(t)))
eq2 = Eq(m_B * diff(U_B(t), t), s_bo / r_bo * (u_s - U_B(t)) + s_ab / r_ab * (U_A(t) - U_B(t)) + s_bc / r_bc * (U_C(t) - U_B(t)) - kappa_b)
eq3 = Eq(m_C * diff(U_C(t), t), s_co / r_co * (u_s - U_C(t)) + s_bc / r_bc * (U_B(t) - U_C(t)))

eqs = [eq1, eq2, eq3]

dsolve(eqs, [U_A(t), U_B(t), U_C(t)])

soln = [U_A(t), U_B(t), U_C(t)]

constants = solve((soln[0].subs(t, 0).subs(U_A(0), 20), soln[1].subs(t, 0).subs(U_B(0), 40), soln[2].subs(t, 0).subs(U_C(0), 40)), {C1, C2, C3})

temperature_A = expand(soln[0].rhs.subs(constants))
temperature_B = soln[1].rhs.subs(constants)
temperature_C = soln[2].rhs.subs(constants)

print()
print()
print("With air-conditioning in B and insulation of walls between A & B, walls between B & C")
pprint("U_A(t) = " + str(temperature_A), use_unicode = True)
print()
pprint("U_B(t) = " + str(temperature_B), use_unicode = True)
print()
pprint("U_C(t) = " + str(temperature_C), use_unicode = True)

start, end = 0, 40

p10 = symplot(temperature_A, (t, start, end), line_color = 'pink', show = False)
p11 = symplot(temperature_B, (t, start, end), line_color = 'gray', show = False)
p12 = symplot(temperature_C, (t, start, end), line_color = 'violet', show = False)

p1.append(p10[0])
p1.append(p11[0])
p1.append(p12[0])



p1.show()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-64-9d44f82f58b6> in <module>
#      36 eqs = [eq1, eq2, eq3]
#      37
# ---> 38 dsolve(eqs, [U_A(t), U_B(t), U_C(t)])
#      39
#      40 soln = [U_A(t), U_B(t), U_C(t)]
#
# ~/.local/lib/python3.6/site-packages/sympy/solvers/ode/ode.py in dsolve(eq, func, hint, simplify, ics, xi, eta, x0, n, **kwargs)
#     606             else:
#     607                 solvefunc = globals()['sysode_nonlinear_%(no_of_equation)seq_order%(order)s' % match]
# --> 608             sols = solvefunc(match)
#     609             if ics:
#     610                 constants = Tuple(*sols).free_symbols - Tuple(*eq).free_symbols
#
# ~/.local/lib/python3.6/site-packages/sympy/solvers/ode/ode.py in sysode_linear_3eq_order1(match_)
#    7675         for j in Add.make_args(eq[i]):
#    7676             if not j.has(x(t), y(t), z(t)):
# ...

# %% [markdown]
# <div style="background-color: #e9e9e9; padding: 10px 20px;">
# Unfortunately, because of sympy limitations non-homogeneous linear ordinary differential equations of order > 2 are not supported. But, code is correct. Solving them by hand is not a smart way I believe.
#
# But, my intuition suggests that air conditioning B would be efficient as it shows effect of cooling on both wall between AB and BC.
#
# Also, as seen in above problem, "adding insulation + air conditioning in B" should be better than just "air conditioning the room B".
# </div>

# %% [markdown]
# #### Question 6
#
# Lets think bigger: can we use this model to construct a system that could generate heating information for a large family of architectural designs? We can, but the first step is going to be to carefully think about how to construct the set of equations.
#
# Lets look at the form of the equations above. If I specify that a house has $N$ rooms with temperatures $U_1,\ldots, U_N$ and give matrices of the form
#
# $$
# M^{-1} = \left[\frac1{M_{i}}\right] = \left[
# \begin{matrix}
# \frac1{M_{1}}
# \\
# \vdots
# \\
# \frac1{M_{N}}
# \end{matrix}\right]\,,
# \hspace{3em}
# U = [U_{i}] = \left[
# \begin{matrix}
# U_1
# \\
# \vdots
# \\
# U_N
# \end{matrix}\right]\,,
# \hspace{3em}
# K = [\kappa_{i}] = \left[
# \begin{matrix}
# \kappa_1
# \\
# \vdots
# \\
# \kappa_N
# \end{matrix}\right]\,.
# $$
#
# Here, $\kappa_i$ represent constant heat sources or sinks, adding or removing $\kappa_i$ J/s of heat. Finally, let $r_{ij} = r_{ji} = \frac{S_{ij}}{R_{ij}}$ and define a matrix
#
# $$
# H = \left[
# \begin{matrix}
# -r_{12} - r_{13} - \ldots - r_{1N} & r_{12} & r_{13} &  \ldots & r_{1N}
# \\
# r_{21} & -r_{21} - r_{23} - \ldots - r_{2N} & r_{23} & \ldots & r_{2N}
# \\
# \vdots & & \ddots &  &\vdots
# \\
# r_{N1} & r_{N2}& r_{N3} & \ldots & -r_{N1} - r_{N2} - \ldots - r_{N,N-1}
# \end{matrix}\right]\,.
# \hspace{3em}
# $$
# Notice that this matrix is symmetric $H^T = H$.
#
# Verify that the system of equations in the 2x2 case can be written as
#
# $$
# U' = M^{-1}H U + k
# $$
#
# and propose a new vector formula which includes a constant outside temperature.

# %% [markdown]
# #### Question 7:
#
# Consider a string of 5 square, $5\times 5$ rooms, with a 6000 kJ heat sink in the center room and the building materials as stipulated before Question 1 and the outside temperature is a constant $35^\circ C$. Let the initial temperature of all rooms be $25^\circ C$. Simulate this situation and find the final equilibrium value.
