# %% [markdown]
# <style>
#     div .question {
#         background-color: lightgray;
#     }
# </style>

# %% [markdown]
# <style>
#     div .question {
#         background-color: #55FF33;
#     }
# </style>

# %% [markdown]
# # Homework:
#
# ## Computation:
#
# ### Problem 1:
#
# <div class="question">
# Explicitly solve the system of equations below:
#
# \begin{align*}
# x_1' &= 2x_1 - 3x_2
# \\
# x_2' &= -4x_1 +3x_2
# \end{align*}
# </div>
#
# Given,
#
# $$
# \begin{pmatrix}
#   x_1'\\
#   x_2'
# \end{pmatrix} = \begin{pmatrix}
#   2 & -3\\
#  -4 & 3
# \end{pmatrix} \begin{pmatrix}
#   x_1\\
#   x_2
# \end{pmatrix}
# $$
#
# For eigen values, det($A - \lambda I$) = $0$.
#
# $$
# \begin{vmatrix}
#   2-\lambda & -3\\
#  -4 & 3-\lambda
# \end{vmatrix} = 0\\
# \implies \lambda^2-5\lambda-6 = 0
# $$
#
# We get, $\lambda_1 = 6$ and $\lambda_2 = -1$ as the eigen values.
#
# With $\lambda_1 = 6$,
# $(A-\lambda I)V = 0$. Substituting $\lambda_1$ and $A$, we get,
#
# $$
# \begin{pmatrix}
#   -4 & -3\\
#  -4 & -3
# \end{pmatrix}\begin{pmatrix}
#   v_1\\
#  v_2
# \end{pmatrix} = 0\\
# \implies 4v_1+3v_2 = 0
# $$
#
# Therefore an eigen vector is,
#
# $$
#                                 V_1 = \begin{pmatrix}
#   -3\\
#  4
# \end{pmatrix}
# $$
#
#
# With $\lambda_2 = -1$,
# $(A-\lambda I)V = 0$. Substituting $\lambda_2$ and $A$, we get,
#
# $$
# \begin{pmatrix}
#   3 & -3\\
#  -4 & 4
# \end{pmatrix}\begin{pmatrix}
#   v_1\\
#  v_2
# \end{pmatrix} = 0\\
# \implies 3v_1-3v_2 = 0
# $$
#
# Therefore an eigen vector is,
#
# $$
#                                 V_2 = \begin{pmatrix}
#   1\\
#  1
# \end{pmatrix}
# $$
#
#
# Hence the solution is of the form,
#
# $$
#                             X(t) = c_1 e^{6t}\begin{pmatrix}
#   -3\\
#  4
# \end{pmatrix} + c_2 e^{-t} \begin{pmatrix}
#   1\\
#  1
# \end{pmatrix}
# $$
#
# The system of equations form a semi-stable node.
#
#
#
# ### Problem 2:
#
# Describe the solutions to the following system of equations:
#
# \begin{align*}
# x_1' &= 2x_1 + 4x_2
# \\
# x_2' &= -x_1 +2x_2
# \end{align*}
#
#
# Given,
#
# $$
# \begin{pmatrix}
#   x_1'\\
#   x_2'
# \end{pmatrix} = \begin{pmatrix}
#   2 & 4\\
#  -1 & 2
# \end{pmatrix} \begin{pmatrix}
#   x_1\\
#   x_2
# \end{pmatrix}
# $$
#
# For eigen values, det($A - \lambda I$) = $0$.
#
# $$
# \begin{vmatrix}
#   2-\lambda & 4\\
#  -1 & 2-\lambda
# \end{vmatrix} = 0\\
# \implies \lambda^2-2\lambda+8 = 0
# $$
#
# We get, $\lambda_1 = 2+2i$ and $\lambda_2 = 2-2i$ as the eigen values.
#
#
# With $\lambda_1 = 2+2i$,
# $(A-\lambda I)V = 0$. Substituting $\lambda_1$ and $A$, we get,
#
# $$
# \begin{pmatrix}
#   2i & 4\\
#  -1 & -2i
# \end{pmatrix}\begin{pmatrix}
#   v_1\\
#  v_2
# \end{pmatrix} = 0\\
# \implies -2iv_1+4v_2 = 0
# $$
#
# Therefore an eigen vector is,
#
# $$
#                                 V_1 = \begin{pmatrix}
#   -2i\\
#  1
# \end{pmatrix}
# $$
#
#
# With $\lambda_2 = 2-2i$,
# $(A-\lambda I)V = 0$. Substituting $\lambda_2$ and $A$, we get,
#
# $$
# \begin{pmatrix}
#   2i & 4\\
#  -1 & 2i
# \end{pmatrix}\begin{pmatrix}
#   v_1\\
#  v_2
# \end{pmatrix} = 0\\
# \implies 2iv_1+4v_2 = 0
# $$
#
# Therefore an eigen vector is,
#
# $$
#                                 V_2 = \begin{pmatrix}
#   2i\\
#  1
# \end{pmatrix}
# $$
#
#
# Hence the solution is of the form,
#
# $$
#                             X(t) = c_1 e^{(2+2i)t}\begin{pmatrix}
#   -2i\\
#  1
# \end{pmatrix} + c_2 e^{(2-2i)t} \begin{pmatrix}
#   2i\\
#  1
# \end{pmatrix}\\
#                             X(t) = e^{2t}\left(c_1 (cos(2t) + i sin(2t)) \begin{pmatrix}
#   -2i\\
#  1
# \end{pmatrix} + c_2 (cos(2t) - i sin(2t)) \begin{pmatrix}
#   2i\\
#  1
# \end{pmatrix}\right)
# $$
#
# Substituing, $c_1 + c_2 = c_3$ and $i(c_1 - c_2) = c_4$, the above equation will be simplified to,
#
# $$
#                             X(t) = e^{2t}\begin{pmatrix}
#   2 c_3 sin(2t) - 2 c_4 cos(2t)\\
#   c_3 cos(2t) + c_4 sin(2t)
# \end{pmatrix}
# $$
#
#
# Since the exponent (2) here is $> 0$, the system of equations form an unstable spiral.
#
#
# ### Problem 3:
#
# Consider the system of equations
#
# \begin{align*}
# x_1' &= -2x_1 + ax_2
# \\
# x_2' &= -ax_1 +3x_2
# \end{align*}
#
# Describe the asymptotic behavior of the solutions for different values of $a$ using the trace determinant plane. What are the phases of the solutions?
#
#
# The eigen equation is,
#
# $$
# \begin{vmatrix}
#   -2-\lambda & a\\
#  -a & 3-\lambda
# \end{vmatrix} = 0\\
# \implies \lambda^2-\lambda-6+a^2 = 0\\
# \implies \lambda = \frac{1 \pm \sqrt{25-4a^2}}{2}
# $$
#
#
# Let $\Delta = 25 - 4a^2$
#
# ##### Case 1 ($\Delta > 0$):
#
# The eigen values are real.
#
# Here, $-\frac{5}{2} < a < \frac{5}{2}$
#
# When $-\frac{5}{2} < a \le -\sqrt{6} \cup \sqrt{6} \le a < \frac{5}{2}$ we have both eigen values either positive/non-negative. Hence unstable nodes.
#
# When $-\sqrt{6} < a < +\sqrt{6}$ we have one eigen value positive and other negative. Hence semistable nodes.
#
#
# ##### Case 2 ($\Delta < 0$):
#
# The eigen values are imaginary.
#
# Here, $a \in \left(-\infty, -\frac{5}{2}\right) \cup \left(\frac{5}{2}, \infty\right)$
#
# Since the exponent of $e$ ($=\frac{1}{2}$) here is $> 0$, the system of equations form an unstable spiral.
#
#
# ##### Case 3 ($\Delta = 0$):
#
# The eigen value is real and repeated.
#
# Here, $a = \pm \frac{1}{2}$.
#
# Since the exponent of $e$ ($=\frac{1}{2}$) here is $> 0$, the system of equations form an unstable inflected node.

# %% [markdown]
# ## Case Study: Cholera Outbreak
#
# #### Background:
#
# Based on [Endemic and Epidemic Dynamics of Cholera: The Role of the Aquatic Reservoir](https://www.researchgate.net/publication/12123535_Endemic_and_Epidemic_Dynamics_of_Cholera_The_Role_of_the_Aquatic_Reservoir) and the textbook.
#
# Cholera is a water born disease that is particularly dangerous in areas where sanitation is inadequate and sewage can find its way into the drinking water supply. Modeling can provide an understanding of the circumstances under which an outbreak can occur. Here we formulate a model that include interacting susceptible and infectious populations. However, what is different from the usual case is twofold: first, we include transmission from the environment and second we imagine tracking the disease over a long period of time and so we include birth and death rates.
#
# #### Governing Equations:
# The variables needed to describe the prevalence of cholera in the population are $S(t)$, susceptible, and $I(t)$, infective, where $t$ is time. Another important variable is the concentration of cholera bacteria in the water supply. We will use $B(t)$ to represent bacterial concentration. This will change in time as more bacteria enter the water supply through ongoing sewage contaminations, which then increases with an increasing number of infected producing cholera bacteria.
#
# #### State Variables:
#
# |Parameter| Description |
# |---|---|
# |$S$| Number of susceptible |
# |$I$| Number of infected |
# |$B$| Concentration of cells in water (cells/ml)|
#
# #### Parameters:
#
# |Parameter| Description | Village 1 |
# |---|---|---|
# |$H$| Total human population |10,000|
# |$a$| Rate of exposure to contaminated water (days$^{-1}$) |.5|
# |$k$| Concentration of bacteria that leads to 50% infection rate (cells/ml) |$10^6$|
# |$r$| Recovery rate (days$^{-1}$) |0.2|
# |$n_b$| Growth/death rate of cholera bacteria in water (days$^{-1}$) |-.33|
# |$e$| Rate of bacteria excretion per person $\left(\frac{\text{cells}}{\text{(ml)(days)(person)}}\right)$|10|
#
# #### Equations:
#
# We set up the following system of differential equations:
#
# \begin{align}
# \frac{dS}{dt} &= -\lambda(B)S\,,
# \\
# \frac{dI}{dt} &= \lambda(B)S - rI\,,
# \\
# \frac{dB}{dt} &= Bn_b + eI\,.
# \end{align}
#
# Here, $\lambda(B)$ is the **force of infection**. We assume that cholera is only contracted through contact with the environment and not through person-to-person contact. The force of infection is the probability per unit time of a susceptible being infected. While we could assume the probability is proportional to the bacterial concentration $B(t)$ times rate of exposure $a$, it is more realistic to assume it is linear for small $B(t)$ and then tends to 1 (100% of infection) as $B$ becomes large. We thus use a standard **hill function**
#
# $$
# \lambda(B) = ap(B) = a\frac{B}{k+B}\,.
# $$
#
# Substituting this in for $\lambda(B)$ we obtain the equations
#
# \begin{align}
# \frac{dS}{dt} &= -a\frac{B}{k+B}S
# \\
# \frac{dI}{dt} &= a\frac{B}{k+B}S - rI
# \\
# \frac{dB}{dt} &= Bn_b + eI
# \end{align}
#
#
# ### Overview:
#
# In the questions below, we will explore whether the equations above can simulation the following situations:
#
# * No outbreak occurs.
# * A finite outbreak occurs.
# * Cyclic outbreak occur as new susceptible population members are added.
#
# We want to understand the relationship between the parameters $a$, $k$, $r$, $n_b$ and $e$ and the outcome of the epidemic.  Since there are three dynamic variables, it is difficult to draw a 2d trajectory diagram based on nullclines. Instead, we will explore the equations numerically, and then use steady state assumptions as derive the critical town size.

# %% [markdown]
# ### Computational Question 1:
#
# Set up the model for the system of differential equations corresponding to Village 1. We want to understand the population size at which an outbreak will occur.
#
# Simulate the equations above for no bacteria and single sick patient, that is $S(0) = H-1$, $I(0) = 1$ and $B(0) = 0$ for
#
# $$
# H = [9000, 11000, 13000, 15000, 17000]
# $$
#
# Plot $S(t)$ vs $I(t)$ for each of the initial populations on the same graph. Be sure to label your axes.
#
# To the nearest 100, what is the smallest value of $H$ for which there is no increase in the number of infected?

# %%
from scipy.integrate import odeint
import matplotlib.pyplot as plt
import numpy as np

# %%
def si_model(X0, t, params):
    S, I, B = X0
    a, k, r, n_b, e = params
    dSdt = -(a * B * S) / (k + B)
    dIdt = (a * B * S) / (k + B) - (r * I)
    dBdt = (B * n_b) + (e * I)
    return [dSdt, dIdt, dBdt]

# %%
H = [9000, 11000, 13000, 15000, 17000]

params = [0.5, 10 ** 6, 0.2, -0.33, 10]

t = np.linspace(0, 1000, 10000)


nrows = 3
ncols = 2
fig, axes = plt.subplots(nrows, ncols, figsize=(10, 10))

row, col = 0, 0
for index, N in enumerate(H):
#     if index != 2:
#         continue
    initial_conditions = [N - 1, 1, 0]
    sol = odeint(si_model, initial_conditions, t, args = (params,))
    axes[row, col].plot(sol[:, 0], sol[:, 1])
    axes[row, col].set_title("H = " + str(N))
    axes[row, col].set_xlabel('S(t)')
    axes[row, col].set_ylabel('I(t)')
    axes[row, col].grid(True)
    col += 1
    if col >= ncols:
        row += 1
        col = 0

fig.delaxes(axes[-1][-1])
fig.tight_layout()

# %% [markdown]
# From the graph 4 (2<sup>nd</sup> row, 2<sup>nd</sup> column), it is evident that the smallest value of $H$ for which there is no increase in the number of infected people is appproximately $13,250$.

# %% [markdown]
# ### Analytic Question 2:
#
# We want to determine the **basic reproduction number** $R_0$ and from it the **critical town size** $S_C$, that is the town size for which a single infected member of the population will lead to an outbreak. To determine if an outbreak will occur, we must determine if a single member of the population can infect more than 1 other member of the population during the time they are sick.
#
# We will estimate the maximum amount of bacteria produced by a single infected $B_1$ will be the equilibrium solution for $B'$ when $I = 1$
#
# $$
# 0 = B' = B_1 n_b + e \hspace{4em} \Rightarrow \hspace{4em} B_1 = -\frac e{n_b}
# $$
#
# For a single infection, we assume that $B_1 << K$, so we can also assume that
#
# $$
# \frac{B_1}{k+B_1} \approx \frac{B_1}{k}\,.
# $$
#
# #### Question 2.a:
#
# Using $B \approx B_1$ when $I=1$, find a formula for the basic reproduction number by solving $I' = 0$. This formula gives a condition for the number of infections to be roughly constant.

# %% [markdown]
# The maximum amount of bacteria produced by a single infected $B_1$ will be the equilibrium solution for $B'$ when $I = 1$
#
# $$
# 0 = B' = B_1 n_b + e \hspace{4em} \implies \hspace{4em} B_1 = -\frac{e}{n_b}
# $$
#
# We also have,
# $$
#                                 \frac{dI}{dt} = a\frac{B}{k+B}S - rI
# $$
#
# At $B_1$, for a single infection, we assume that $B_1 << k$. Hence the above equation becomes,
# $$
#                                 \frac{dI}{dt} \approx \frac{aB_1S}{k} - r
# $$
#
# For Basic Reproduction Number, we must have, $\frac{dI}{dt} = 0$. Hence,
#
# $$
# \begin{align}
#                                           0 &= \frac{aB_1S_0}{k} - rI\\
#                                           I &= \frac{a S_0}{k} \times -\frac{e}{n_b} \times \frac{1}{r}\\
#                                             &= -\frac{aeS_0}{rkn_b}\\
#                                             &= \frac{aeS_0}{rk|n_b|}
# \end{align}
# $$
#
# Therefore, Basic Reproduction Number, $R_0 = \frac{a e s_0}{r k |n_b|}$.

# %% [markdown]
# #### Question 2.b:
#
# The number of infected will increase if $R_0 \geq 1$. Solve for an expression for the **critical town size** $S_0$ such that $R_0 < 1$.

# %% [markdown]
# We know that, number of infected will increase if $R_0 \geq 1$. For critical town size $S_c$, we have $R_0 < 1$, we have,
# $$
# \begin{align}
#                                     R_0 &< 1\\
#                                     \frac{aeS_c}{rk|n_b|} &< 1\\
#                                     S_c &< \boxed{\frac{r k |n_b|}{a e}}\\
# \end{align}
# $$

# %% [markdown]
# ### Computational Question 3:
#
# Ultimately, we want to construct a kind of "phase space" for the parameters so we can understand clearly how different starting conditions lead to different kinds of outcomes, and hopefully to prevent outbreaks. Using your formula from Question 2 we want to use the critical town size to evaluate the changing of different parameters.
#
# #### Question 3.a:
#
# Fix all quantities as in the table in the case study. Construct a phase plot for the parameters
#
# 1. $S_0$ vs $e$, $a = .5$,
# 2. $S_0$ vs $a$, $e = 10$,
# 3. $a$ vs $e$, $S_0 = 10,000$,
#
# by plotting the line $R_0 = 1$. Clearly describe for which values of the parameters on each chart the outbreak will occur.

# %%
def hyperbola(x, c):
    return c / x

def plot_hyperbola(x, c, var_x, var_y):
    y = hyperbola(x, c)
    plt.plot(x, y, label=var_x + " vs " + var_y)
#     plt.fill(x, y)
    plt.legend()
    plt.show()

# %% [markdown]
# 1. $S_c$ vs $e$, $a = 0.5$
#
# The equation becomes,
# $$
#                                 S_ce = \frac{0.2 \times 10^6 \times 0.33}{0.5} = 132,000
# $$

# %%
x = np.linspace(0.2, 10, 500)
c = 132000
plot_hyperbola(x, c, "Sc", "e")

# %% [markdown]
# For combination of $S_c$, $e$ above/on the blue curve, we have an outbreak.

# %% [markdown]
# 2. $S_c$ vs $a$, $e = 10$
#
# The equation becomes,
# $$
#                                 S_ca = \frac{0.2 \times 10^6 \times 0.33}{10} = 6,600
# $$

# %%
x = np.linspace(0.2, 5, 500)
c = 6600
plot_hyperbola(x, c, "Sc", "a")

# %% [markdown]
# For combination of $S_c$, $a$ above/on the blue curve, we have an outbreak.

# %% [markdown]
# 3. $a$ vs $e$, $S_c = 10,000$
#
# The equation becomes,
# $$
#                                 ea = \frac{0.2 \times 10^6 \times 0.33}{10000} = 6.6
# $$

# %%
x = np.linspace(0.2, 5, 500)
c = 6.6
plot_hyperbola(x, c, "e", "a")

# %% [markdown]
# For combination of $e$ vs $a$ above/on the blue curve, we have an outbreak.

# %% [markdown]
# #### Question 3.b:
#
# Given the initial starting values, if it is equally easy to increase/decrease $e$ and $a$ by a fixed percentage, which would be the most efficient variable to adjust?

# %% [markdown]
# Since the increase/decrease of $e$ and $a$ is equally easy, the change in $a$ will have an effect on both terms, namely, $\frac{dS}{dt}$ and $\frac{dI}{dt}$, where as, change in $e$ will have an effect on only one term, i.e., $\frac{dB}{dt}$. Hence, I prefer to change $e$ over $a$.

# %% [markdown]
# ### Analytic Question 4:
#
# Assume that after a time the population becomes susceptible again. We will model this situation by adding a recovered population that slowly moves back into the susceptible population.
#
# \begin{align}
# \frac{dS}{dt} &= -a\frac{B}{k+B}S + dR
# \\
# \frac{dI}{dt} &= a\frac{B}{k+B}S - rI
# \\
# \frac{dB}{dt} &= Bn_b + eI
# \\
# \frac{dR}{dt} &= rI - dR
# \end{align}
#
# #### Problem 4.a:
#
# Find the equilibrium (constant) solutions to the equations above, that is the solutions with $S' = I' = B' = R' = 0$. There are different numbers of equilibrium solutions for different values of the parameters. Classify these behaviors.

# %% [markdown]
# Let, $N(t)$ be the total population. Hence, at any instance of time we have,
#
# $$
#                                         N(t) = S(t) + I(t) + R(t)
# $$
#
# For equilibrium solutions, we have,
#
# $$
#                                         \frac{dS}{dt} = 0\\
#                                         \frac{dI}{dt} = 0\\
#                                         \frac{dB}{dt} = 0\\
#                                         \frac{dR}{dt} = 0\\
# $$
#
# Assumptions:
#
# 1. $n_b < 0$
# 2. $S$ is the independent variable
#
# Combining these equations with models in the question,
#
# $$
#                                     a\frac{B}{k+B}S = dR\\
#                                     a\frac{B}{k+B}S = rI\\
#                                     B|n_b| = eI\\
#                                     rI = dR
# $$
#
# The trivial equilibrium solutions can be clearly identified as $S = 0$, $I = 0$, $B = 0$, $R = 0$.
#
# Other than this we have a have a family of equilibrium solutions that can be found as follows. We will try to find the family of solutions in terms of the initial number of Susceptibles $S$, assuming $S$ as the independent variable.
#
# Equation 4 above is redundant as it can be obtained from equation 1 and equation 2.
#
# From equation 3 above, we get,
#
# $$
#                                     B = \frac{eI}{|n_b|}
# $$
#
# Substituting this is in equation 2,  we get,
#
# $$
#                                     I = \frac{aeS-rk|n_b|}{re}
# $$
#
# Substituting in equation 3, we get,
#
# $$
#                                     B = \frac{e}{|n_b|}I = \frac{aeS-rk|n_b|}{r|n_b|}
# $$
#
# Substituting in equation 4, we get,
#
# $$
#                                     R = \frac{r}{d}I = \frac{aeS-rk|n_b|}{de}
# $$
#
# Hence, the family of equibrium solutions is,
#
# $$
#         \left(S, I, B, R\right) = \left(S, \frac{aeS-rk|n_b|}{re}, \frac{aeS-rk|n_b|}{r|n_b|}, \frac{aeS-rk|n_b|}{de}\right)
# $$
#
# It can be clearly seen that all of them are linearly dependent on $S$ and all of them increase as $S$ increases.

# %% [markdown]
# #### Problem 4.b:
#
# Numerically solve for an example where there is an equilibrium solution with nonzero $I$ using an initial value of $S(0)$ above the critical size and $I(0) = 1$. Plot the result and describe the behavior .

# %%
def sir_model(X0, t, params):
    S, I, B, R = X0
    a, k, d, r, n_b, e = params
    dSdt = -(a * B * S) / (k + B) + (d * R)
    dIdt = (a * B * S) / (k + B) - (r * I)
    dBdt = (B * n_b) + (e * I)
    dRdt = (r * I) - (d * R)
    return [dSdt, dIdt, dBdt, dRdt]

def equilibrium_solutions(S, params):
    a, k, d, r, n_b, e = params
    I = ((a * e * S) - (r * k * abs(n_b))) / (r * e)
    B = ((a * e * S) - (r * k * abs(n_b))) / (r * abs(n_b))
    R = ((a * e * S) - (r * k * abs(n_b))) / (d * e)
    return [round(S, 2), round(I, 2), round(B, 2), round(R, 2)]

# %%
H = [9000, 11000, 13000, 15000, 17000, 20000]

params = [0.5, 10 ** 6, 0.3, 0.2, -0.33, 10]

t = np.linspace(0, 1000, 10000)

nrows = len(H)
ncols = 4
fig, axes = plt.subplots(nrows, ncols, figsize=(16, 16))
y_labels = ["S(t)", "I(t)", "B(t)", "R(t)"]

for index, N in enumerate(H):
#     if index != 2:
#         continue
    print("\n\n" + "Total population = " + str(N));
    initial_conditions = [N - 1, 1, 0, 0]
    model = sir_model(initial_conditions, t, params)
    print("numerical solution = [" + str(round(model[0], 2)) + ", " + str(round(model[1], 2))
          + ", " + str(round(model[2], 2)) + ", " + str(round(model[3], 2)) + "]")
    print("equilibrium solutions = " + str(equilibrium_solutions(initial_conditions[0], params)))
    sol = odeint(sir_model, initial_conditions, t, args = (params,))
    for col in range(ncols):
        axes[index, col].plot(t, sol[:, col])
        axes[index, col].set_title(y_labels[col] + " vs t. N = " + str(H[index]))
        axes[index, col].set_xlabel("t")
        axes[index, col].set_ylabel(y_labels[col])
        axes[index, col].grid(True)

# fig.delaxes(axes[-1][-1])
fig.tight_layout()
# Out:
# Total population = 9000
# numerical solution = [0.0, -0.2, 10.0, 0.2]
# equilibrium solutions = [8999, -10502.5, -318257.58, -7001.67]
#
#
# Total population = 11000
# numerical solution = [0.0, -0.2, 10.0, 0.2]
# equilibrium solutions = [10999, -5502.5, -166742.42, -3668.33]
#
#
# Total population = 13000
# numerical solution = [0.0, -0.2, 10.0, 0.2]
# equilibrium solutions = [12999, -502.5, -15227.27, -335.0]
#
#
# Total population = 15000
# numerical solution = [0.0, -0.2, 10.0, 0.2]
# equilibrium solutions = [14999, 4497.5, 136287.88, 2998.33]
#
#
# Total population = 17000
# numerical solution = [0.0, -0.2, 10.0, 0.2]
# equilibrium solutions = [16999, 9497.5, 287803.03, 6331.67]
#
#
# Total population = 20000
# numerical solution = [0.0, -0.2, 10.0, 0.2]
# equilibrium solutions = [19999, 16997.5, 515075.76, 11331.67]
